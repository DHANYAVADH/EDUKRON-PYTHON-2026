# %%
# Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577


a = 3.14
b = 2.718
c = 1.618
d = 0.577

total = a + b + c + d
count = 4   

average = total / count

print("Average:", average)

# %% [markdown]
# IF WE KNOW NUMBERS THEN COUNT=4
#
#   IF INPUT GIVEN BY USER
#   numbers = input("Enter numbers separated by space: ")
#
# num_list = numbers.split()   # Split input into list
#
# total = 0
# count = 0   # We don't know how many numbers
#
# for num in num_list:
#     total = total + float(num)
#     count = count + 1
#
# average = total / count
#
# print("Average:", average)

# %%
# Question 2: Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)


fahrenheit = 98.6

celsius = (fahrenheit - 32) * 5 / 9

print("Temperature in Celsius:", celsius)

# %%
# Question 3: Calculate the compound interest on $1000 at 5.5% for 3 years


principal = 1000
rate = 5.5 / 100   # Convert percentage to decimal
time = 3

# Compound Interest Formula:
# A = P * (1 + r) ** t
amount = principal * (1 + rate) ** time

compound_interest = amount - principal

print("Final Amount:", amount)
print("Compound Interest:", compound_interest)

# %% [markdown]
# WE HAVE CONVERT 5.5% TO DECIMAL SO WE HAVE TO  DIVIDE BY 100
#
# Whenever you see % in programming:
# ==> Always divide by 100
# ==> Convert it into decimaL

# %%
# Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2
a = 3.5
b = 4.2


# hypotenuse = √(a² + b²)

hypotenuse = (a**2 + b**2) ** 0.5

print("Hypotenuse:", hypotenuse)
# Out:
# Hypotenuse: 5.4671747731346585

# %%
# Question 5: Calculate the volume of a sphere with radius 7.8


radius = 7.8
pi = 3.14159

# Volume formula:
# V = (4/3) * π * r^3

volume = (4/3) * pi * (radius ** 3)

print("Volume of the sphere:", volume)
# Out:
# Volume of the sphere: 1987.7970902399995

# %%
# Question 6: Round 3.14159 to 3 decimal places

number = 3.14159

rounded_number = round(number, 3)

print("Rounded value:", rounded_number)
# Out:
# Rounded value: 3.142

# %%
# Question 7: Calculate the percentage: 45 out of 67


part = 45
total = 67

percentage = (part / total) * 100

print("Percentage:", percentage)
# Out:
# Percentage: 67.16417910447761

# %%
# Question 8: Find the square root of 23.456


number = 23.456

# Square root using power 0.5
square_root = number ** 0.5

print("Square root:", square_root)
# Out:
# Square root: 4.843139477652899

# %%
# Question 9: Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years


principal = 2500
rate = 6.5 / 100   
time = 2.5

# Simple Interest Formula:
# SI = P * r * t

simple_interest = principal * rate * time

print("Simple Interest:", simple_interest)
# Out:
# Simple Interest: 406.25

# %%
# Question 10: Convert 45.7 degrees to radians


degrees = 45.7
pi = 3.14159

# Formula:
# radians = degrees * (pi / 180)

radians = degrees * (pi / 180)

print("Radians:", radians)
